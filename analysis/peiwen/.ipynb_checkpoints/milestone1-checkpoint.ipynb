# %%
import numpy as np
import pandas as pd

df=pd.read_csv('AirQualityUCI.csv')

print(df.head(20))
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0   2004/3/10  18:00:00     2.6       1360.0     150.0      11.9
# 1   2004/3/10  19:00:00     2.0       1292.0     112.0       9.4
# 2   2004/3/10  20:00:00     2.2       1402.0      88.0       9.0
# 3   2004/3/10  21:00:00     2.2       1376.0      80.0       9.2
# 4   2004/3/10  22:00:00     1.6       1272.0      51.0       6.5
# 5   2004/3/10  23:00:00     1.2       1197.0      38.0       4.7
# 6   2004/3/11   0:00:00     1.2       1185.0      31.0       3.6
# 7   2004/3/11   1:00:00     1.0       1136.0      31.0       3.3
# 8   2004/3/11   2:00:00     0.9       1094.0      24.0       2.3
# 9   2004/3/11   3:00:00     0.6       1010.0      19.0       1.7
# 10  2004/3/11   4:00:00  -200.0       1011.0      14.0       1.3
# 11  2004/3/11   5:00:00     0.7       1066.0       8.0       1.1
# 12  2004/3/11   6:00:00     0.7       1052.0      16.0       1.6
# ...
